# %% [markdown]
# # Import Labrary

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Dataset

# %%
tw=pd.read_csv("C:\\Users\\absub\\Downloads\\sample.csv")
tw
# Out:
#                   Tweet Id                                          Tweet URL  \
# 0    "1167429261210218497"  https://twitter.com/animalhealthEU/status/1167...
# 1    "1167375334670557185"  https://twitter.com/PennyBrohnUK/status/116737...
# 2    "1167237977615097861"  https://twitter.com/lordbyronaf/status/1167237...
# 3    "1167236897078480898"  https://twitter.com/CountessDavis/status/11672...
# 4    "1167228378191204353"  https://twitter.com/Local12/status/11672283781...
# ..                     ...                                                ...
# 381  "1145652120034717696"  https://twitter.com/UKNOAH/status/114565212003...
# 382  "1145637718493290497"  https://twitter.com/EMOverEasy/status/11456377...
# 383  "1145628612739174400"  https://twitter.com/SIMV_RP/status/11456286127...
# 384  "1145621305825341440"  https://twitter.com/wameyokw/status/1145621305...
# 385  "1145609117618397184"  https://twitter.com/animalhealthEU/status/1145...
#
#     Tweet Posted Time (UTC)  \
# ...

# %%
#Taking first five information of dataset
tw.head()
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1167429261210218497"  https://twitter.com/animalhealthEU/status/1167...
# 1  "1167375334670557185"  https://twitter.com/PennyBrohnUK/status/116737...
# 2  "1167237977615097861"  https://twitter.com/lordbyronaf/status/1167237...
# 3  "1167236897078480898"  https://twitter.com/CountessDavis/status/11672...
# 4  "1167228378191204353"  https://twitter.com/Local12/status/11672283781...
#
#   Tweet Posted Time (UTC)                                      Tweet Content  \
# 0    30 Aug 2019 13:30:00  Pets change our lives &amp; become a part of o...
# 1    30 Aug 2019 09:55:43  Another spot of our #morethanmedicine bus in #...
# 2    30 Aug 2019 00:49:54  What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
# 3    30 Aug 2019 00:45:37  What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
# 4    30 Aug 2019 00:11:46  What a great team ⁦@HealthSourceOH⁩ ⁦@Local12⁩...
#
# ...

# %%
#Taking the last five information from dataset
tw.tail()
# Out:
#                   Tweet Id                                          Tweet URL  \
# 381  "1145652120034717696"  https://twitter.com/UKNOAH/status/114565212003...
# 382  "1145637718493290497"  https://twitter.com/EMOverEasy/status/11456377...
# 383  "1145628612739174400"  https://twitter.com/SIMV_RP/status/11456286127...
# 384  "1145621305825341440"  https://twitter.com/wameyokw/status/1145621305...
# 385  "1145609117618397184"  https://twitter.com/animalhealthEU/status/1145...
#
#     Tweet Posted Time (UTC)  \
# 381    01 Jul 2019 11:15:25
# 382    01 Jul 2019 10:18:11
# 383    01 Jul 2019 09:42:00
# 384    01 Jul 2019 09:12:58
# 385    01 Jul 2019 08:24:32
#
#                                          Tweet Content Tweet Type  \
# 381  #MorethanMedicine What does this mean? 🤔\nBy p...    ReTweet
# 382  After a great weekend at #rebellion19 we are b...      Tweet
# 383  #MorethanMedicine What does this mean? 🤔\nBy p...    ReTweet
# ...

# %%
#Taking information about columns
tw.columns
# Out:
# Index(['Tweet Id', 'Tweet URL', 'Tweet Posted Time (UTC)', 'Tweet Content',
#        'Tweet Type', 'Client', 'Retweets Received', 'Likes Received',
#        'Tweet Location', 'Tweet Language', 'User Id', 'Name', 'Username',
#        'User Bio', 'Verified or Non-Verified', 'Profile URL',
#        'Protected or Non-protected', 'User Followers', 'User Following',
#        'User Account Creation Date', 'Impressions'],
#       dtype='object')

# %%
#Taking information about number of row and column
tw.shape
# Out:
# (386, 21)

# %%
#More details about Dataset
tw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Tweet Id                    386 non-null    object
#  1   Tweet URL                   386 non-null    object
#  2   Tweet Posted Time (UTC)     386 non-null    object
#  3   Tweet Content               386 non-null    object
#  4   Tweet Type                  386 non-null    object
#  5   Client                      386 non-null    object
#  6   Retweets Received           386 non-null    int64
#  7   Likes Received              386 non-null    int64
#  8   Tweet Location              325 non-null    object
#  9   Tweet Language              385 non-null    object
#  10  User Id                     386 non-null    object
#  11  Name                        386 non-null    object
#  12  Username                    386 non-null    object
# ...

# %%
#Taking statistical information about dataset
tw.describe()
# Out:
#        Retweets Received  Likes Received  User Followers  User Following  \
# count         386.000000      386.000000      386.000000      386.000000
# mean            0.730570        2.839378     2516.904145     1067.401554
# std             1.884991        9.423381    10529.124870     1409.750825
# min             0.000000        0.000000        0.000000        4.000000
# 25%             0.000000        0.000000      348.000000      379.000000
# 50%             0.000000        0.000000      796.000000      542.000000
# 75%             0.000000        1.000000     2922.500000     1123.000000
# max            13.000000       98.000000   198675.000000    12476.000000
#
#         Impressions
# count    386.000000
# mean    1137.849741
# std     2381.107457
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      882.000000
# max    12033.000000

# %% [markdown]
# # Data Visualization

# %%
tw['Tweet Location'].value_counts()
# Out:
# Brussels                    37
# Brussels,  Belgium          28
# Columbus, OH                19
# Columbus,OH                 18
# DK Diner, USA               17
#                             ..
# Cincinnati, OH               1
# Columbus, Ohio               1
# Tala                         1
# Celldömölk, Magyarország     1
# in my happy place            1
# Name: Tweet Location, Length: 105, dtype: int64

# %%
#Getting top_10 Tweet Location
tw['Tweet Location'].value_counts()[0:10]
# Out:
# Brussels                   37
# Brussels,  Belgium         28
# Columbus, OH               19
# Columbus,OH                18
# DK Diner, USA              17
# Bristol, England           11
# Basel, Switzerland         11
# Pill, Bristol              10
# Kingdom of Saudi Arabia     9
# Bristol, United Kingdom     8
# Name: Tweet Location, dtype: int64

# %%
#plot bar graph
plt.xlabel("Tweet Location")
plt.ylabel("count")
plt.title('Distribution of Tweet Location')
plt.bar(tw['Tweet Location'].value_counts().keys()[0:10],tw['Tweet Location'].value_counts()[0:10])
plt.show()

# %%
tw['Tweet Language'].value_counts()
# Out:
# English    380
# German       4
# Polish       1
# Name: Tweet Language, dtype: int64

# %%
#plot bar graph
plt.xlabel("Tweet Language")
plt.ylabel("count")
plt.title('Distribution of Tweet Language')
c=['r','m','y']
plt.bar(list(tw['Tweet Language'].value_counts().keys()),list(tw['Tweet Language'].value_counts()),color=c,label=['English','German','Polish'])
plt.legend()
plt.show()

# %%
#Plot pie chart
plt.title("Pie Chart")
plt.pie(list(tw['Tweet Language'].value_counts()),labels=list(tw['Tweet Language'].value_counts().keys()),autopct="%0.2f%%")
plt.show()

# %%
tw['Tweet Type'].value_counts()
# Out:
# ReTweet    276
# Tweet       95
# Reply       15
# Name: Tweet Type, dtype: int64

# %%
#plot bar graph
plt.xlabel("Tweet Type")
plt.ylabel("count")
plt.title('Distribution of Tweet Type')
c=['r','m','y']
plt.bar(list(tw['Tweet Type'].value_counts().keys()),list(tw['Tweet Type'].value_counts()),color=c,label=['ReTweet','Tweet','Reply'])
plt.legend()
plt.show()

# %% [markdown]
# # Thank You
